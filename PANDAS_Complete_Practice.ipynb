# %% [markdown]
# <a href="https://colab.research.google.com/github/saikumarreddykorsapati-source/LEARN-/blob/main/PANDAS_Complete_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/sample_data/california_housing_test.csv")
df
# Out:
#       longitude  latitude  ...  median_income  median_house_value
# 0       -122.05     37.37  ...         6.6085            344700.0
# 1       -118.30     34.26  ...         3.5990            176500.0
# 2       -117.81     33.78  ...         5.7934            270500.0
# 3       -118.36     33.82  ...         6.1359            330000.0
# 4       -119.67     36.33  ...         2.9375             81700.0
# ...         ...       ...  ...            ...                 ...
# 2995    -119.86     34.42  ...         1.1790            225000.0
# 2996    -118.14     34.06  ...         3.3906            237200.0
# 2997    -119.70     36.30  ...         2.2895             62000.0
# 2998    -117.12     34.10  ...         3.2708            162500.0
# 2999    -119.63     34.42  ...         8.5608            500001.0
#
# [3000 rows x 9 columns]

# %%
df['new_col'] = 'sai'

# %%
df.head(2)
# Out:
#    longitude  latitude  ...  median_house_value  new_col
# 0    -122.05     37.37  ...            344700.0      sai
# 1    -118.30     34.26  ...            176500.0      sai
#
# [2 rows x 10 columns]

# %%
df.tail(2)
# Out:
#       longitude  latitude  ...  median_house_value  new_col
# 2998    -117.12     34.10  ...            162500.0      sai
# 2999    -119.63     34.42  ...            500001.0      sai
#
# [2 rows x 10 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['longitude'])
# Out:
# pandas.core.series.Series

# %%
type(df[['longitude']]) # if we put list in a list or double square brackets then a series will be treated as DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
df['longitude','latitude'] # if we want to access more than one columns from data frame we should use Double Brackets ie., 
#we can access one column in case of series, if we want access more than one we should use data frame
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('longitude', 'latitude')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df[['longitude','latitude']] # resolution for above issue
# Out:
#       longitude  latitude
# 0       -122.05     37.37
# 1       -118.30     34.26
# 2       -117.81     33.78
# 3       -118.36     33.82
# 4       -119.67     36.33
# ...         ...       ...
# 2995    -119.86     34.42
# 2996    -118.14     34.06
# 2997    -119.70     36.30
# 2998    -117.12     34.10
# 2999    -119.63     34.42
#
# [3000 rows x 2 columns]

# %%
df.info() # used to show over all information of the data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
df.dtypes # used to show data types of the columns
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
df.describe() # provides description or statstical view of whole data frame, By default int,float values will be considered
# Out:
#          longitude    latitude  ...  median_income  median_house_value
# count  3000.000000  3000.00000  ...    3000.000000          3000.00000
# mean   -119.589200    35.63539  ...       3.807272        205846.27500
# std       1.994936     2.12967  ...       1.854512        113119.68747
# min    -124.180000    32.56000  ...       0.499900         22500.00000
# 25%    -121.810000    33.93000  ...       2.544000        121200.00000
# 50%    -118.485000    34.27000  ...       3.487150        177650.00000
# 75%    -118.020000    37.69000  ...       4.656475        263975.00000
# max    -114.490000    41.92000  ...      15.000100        500001.00000
#
# [8 rows x 9 columns]

# %%
df.dtypes==object
# Out:
# longitude             False
# latitude              False
# housing_median_age    False
# total_rooms           False
# total_bedrooms        False
# population            False
# households            False
# median_income         False
# median_house_value    False
# new_col                True
# dtype: bool

# %%
df1 = df[df.dtypes[df.dtypes == 'object'].index]
df1.describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df.describe(include='all') # by using this we can describe whole data set both int,float along with string type as well
# Out:
#           longitude    latitude  ...  median_house_value  new_col
# count   3000.000000  3000.00000  ...          3000.00000     3000
# unique          NaN         NaN  ...                 NaN        1
# top             NaN         NaN  ...                 NaN      sai
# freq            NaN         NaN  ...                 NaN     3000
# mean    -119.589200    35.63539  ...        205846.27500      NaN
# std        1.994936     2.12967  ...        113119.68747      NaN
# min     -124.180000    32.56000  ...         22500.00000      NaN
# 25%     -121.810000    33.93000  ...        121200.00000      NaN
# 50%     -118.485000    34.27000  ...        177650.00000      NaN
# 75%     -118.020000    37.69000  ...        263975.00000      NaN
# max     -114.490000    41.92000  ...        500001.00000      NaN
#
# [11 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'new_col'],
#       dtype='object')

# %%
df.to_csv("test.csv",index=False,sep = "#", columns=['longitude','latitude']) # used to convert our data into csv format and auto downloaded to our local machine

# %%
# !ls # used to list files in our local machine
# Out:
# sample_data  test.csv

# %%
# !pwd # present working directory
# Out:
# /content

# %%
df1 = pd.read_csv("/content/sample_data/california_housing_test.csv", sep=",", header=None, skiprows=[0], na_values=['42','-122.05','661.0'], names=['O','T','Th','F','Fi','S','Sev','E','N'])
df1
# Out:
#            O      T    Th       F      Fi       S     Sev       E         N
# 0        NaN  37.37  27.0  3885.0     NaN  1537.0   606.0  6.6085  344700.0
# 1    -118.30  34.26  43.0  1510.0   310.0   809.0   277.0  3.5990  176500.0
# 2    -117.81  33.78  27.0  3589.0   507.0  1484.0   495.0  5.7934  270500.0
# 3    -118.36  33.82  28.0    67.0    15.0    49.0    11.0  6.1359  330000.0
# 4    -119.67  36.33  19.0  1241.0   244.0   850.0   237.0  2.9375   81700.0
# ...      ...    ...   ...     ...     ...     ...     ...     ...       ...
# 2995 -119.86  34.42  23.0  1450.0   642.0  1258.0   607.0  1.1790  225000.0
# 2996 -118.14  34.06  27.0  5257.0  1082.0  3496.0  1036.0  3.3906  237200.0
# 2997 -119.70  36.30  10.0   956.0   201.0   693.0   220.0  2.2895   62000.0
# 2998 -117.12  34.10  40.0    96.0    14.0    46.0    14.0  3.2708  162500.0
# 2999 -119.63  34.42   NaN  1765.0   263.0   753.0   260.0  8.5608  500001.0
#
# [3000 rows x 9 columns]

# %%
df2 = pd.read_excel('E:/Downloads/sample-excel-master/LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx',sheet_name='Create your instrument universe')

# %%
df4 = pd.read_html("https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool")

# %%
type(df4)
# Out:
# list

# %%
len(df4)
# Out:
# 6

# %%
df4[0].head(2)
# Out:
#     Season  ...                                    PTS
# 0  2008-09  ...  Did Not Play (other pro league—Spain)
# 1  2009-10  ...                                    6.3
#
# [2 rows x 30 columns]

# %%
df4[5].head(2)
# Out:
#     Season   Age   Tm   Lg Pos     G  ...  WS/48  Unnamed: 24  OBPM  DBPM  BPM  VORP
# 0  2009-10  20.0  OKC  NBA  PF   6.0  ...  0.144          NaN  -1.0   2.0  0.9   0.1
# 1  2010-11  21.0  OKC  NBA  PF  17.0  ...  0.109          NaN  -1.6   0.8 -0.8   0.1
#
# [2 rows x 29 columns]

# %%
html_data = pd.read_html("https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool")
for i in range(len(html_data)):
    html_data[i].to_csv(f"html_data{i}.csv", index=False)

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
s = """{
"name" :"sudh",
"phone_no" : 45454545,
"comp":["iNeuron", "EY" , "unilver" , "verizon" , "deloitte" , "wipro"]
}
"""

# %%
import json

# %%
js = json.loads(s)

# %%
js
# Out:
# {'comp': ['iNeuron', 'EY', 'unilver', 'verizon', 'deloitte', 'wipro'],
#  'name': 'sudh',
#  'phone_no': 45454545}

# %%
pd.DataFrame(js,columns=['comp'])
# Out:
#        comp
# 0   iNeuron
# 1        EY
# 2   unilver
# 3   verizon
# 4  deloitte
# 5     wipro

# %%
import requests

# %%
res = requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
res
# Out:
# <Response [200]>

# %%
js = res.json()

# %%
js1 = pd.DataFrame(js).head(3)

# %% [markdown]
# 22 ) Pandas Basic

# %%
js
# Out:
# [{'active_lock_reason': None,
#   'assignee': None,
#   'assignees': [],
#   'author_association': 'CONTRIBUTOR',
#   'body': '- [✔ ] closes #45311\r\n- [✔] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [✔] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [X] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'closed_at': None,
#   'comments': 0,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45797/comments',
#   'created_at': '2022-02-03T04:08:23Z',
#   'draft': False,
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45797/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/45797',
#   'id': 1122630691,
#   'labels': [],
# ...

# %%
js[0]['title']
# Out:
# 'Test series replace different numpy int'

# %%
for i in range(len(js)):
  print(js[i]['title'])
# Out:
# Test series replace different numpy int
# BUG: Series[Interval].fillna(mismatched) coerce instead of raise
# DEP: Protect some ExcelWriter attributes
# BUG: Error writing an empty DataFrame to an ods file
# BUG: Error writing an empty DataFrame to an ods file
# BUG: `df.to_hdf` fails when `DatetimeIndex` has `freq=pd.DateOffset(years=1)`
# BUG: Date time slicing fails for `freq=pd.DateOffset(years=1)`
# BUG: loc raising uncontrolled error when more indexers than levels
# TST: Skip flaky, crashing test in Windows
# Regression: Loc raising when indexing mi with one level
# BUG: Apply with one row unexpected behaviour - It sorts columns
# Enhance consistency on Styler hide methods
# BUG: Accessing a one-level MultiIndex with `.loc` raises with an unclear error (in 1.4)
# ENH: support masked arrays in hashtable-based functions (duplicated, isin, mode)
# Lose the index before 'na_value' assignment in 'to_numpy'
# BUG: Multi-indexed Series to Numpy fails when `na_value` supplied
# ...

# %%
len(js)
# Out:
# 30

# %%
js1.head(2)
# Out:
#                                                  url  ... performed_via_github_app
# 0  https://api.github.com/repos/pandas-dev/pandas...  ...                     None
# 1  https://api.github.com/repos/pandas-dev/pandas...  ...                     None
#
# [2 rows x 29 columns]

# %%
pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues").head(2)
# Out:
#                                                  url  ... performed_via_github_app
# 0  https://api.github.com/repos/pandas-dev/pandas...  ...                      NaN
# 1  https://api.github.com/repos/pandas-dev/pandas...  ...                      NaN
#
# [2 rows x 29 columns]

# %%
lis=[]
for i in range(len(js)):
    lis.append(js[i]['user'])
pd.DataFrame(lis).head(2)
# Out:
#           login        id  ...  type site_admin
# 0       weikhor  36619387  ...  User      False
# 1  jbrockmendel   8078968  ...  User      False
#
# [2 rows x 18 columns]

# %%
user = []
res=requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')
js=res.json()
for i in range(len(js)):
    user.append(js[i]['user'])

pd.DataFrame(user).head(2)
# Out:
#           login        id  ...  type site_admin
# 0       weikhor  36619387  ...  User      False
# 1  jbrockmendel   8078968  ...  User      False
#
# [2 rows x 18 columns]

# %%
pd.DataFrame([js[i]["user"] for i in range(len(js))]).head(2)
# Out:
#           login        id  ...  type site_admin
# 0       weikhor  36619387  ...  User      False
# 1  jbrockmendel   8078968  ...  User      False
#
# [2 rows x 18 columns]

# %%
l = []
for i in range(len(js)):
    l.append(js[i]['user'])
    
pd.DataFrame(l).head(2)
# Out:
#           login        id  ...  type site_admin
# 0       weikhor  36619387  ...  User      False
# 1  jbrockmendel   8078968  ...  User      False
#
# [2 rows x 18 columns]

# %%
json_data = pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
data = pd.DataFrame.from_records(json_data['user'])
data.head(2)
# Out:
#           login        id  ...  type site_admin
# 0       weikhor  36619387  ...  User      False
# 1  jbrockmendel   8078968  ...  User      False
#
# [2 rows x 18 columns]

# %%
form_file = pd.read_csv("html_data1.csv")

# %%
form_file.to_pickle("my_pickle")

# %%
form_file.head(2)
# Out:
#     Season   Age   Tm   Lg Pos     G    GS  ...  TRB  AST  STL  BLK  TOV   PF  PTS
# 0  2009-10  20.0  OKC  NBA  PF   6.0   0.0  ...  6.5  0.3  0.3  2.0  1.0  3.2  7.8
# 1  2010-11  21.0  OKC  NBA  PF  17.0  17.0  ...  7.3  0.2  0.2  3.1  1.2  3.8  9.8
#
# [2 rows x 30 columns]

# %%
import pandas as pd

# %%
# !pip install --upgrade tables

# %%
h5_data = pd.HDFStore('test.h5')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-164-1dd0ea5d7bad> in <module>()
# ----> 1 h5_data = pd.HDFStore('test.h5')
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/pytables.py in __init__(self, path, mode, complevel, complib, fletcher32, **kwargs)
#     570             raise ValueError("format is not a defined argument for HDFStore")
#     571
# --> 572         tables = import_optional_dependency("tables")
#     573
#     574         if complib is not None and complib not in tables.filters.all_complibs:
#
# /usr/local/lib/python3.7/dist-packages/pandas/compat/_optional.py in import_optional_dependency(name, extra, errors, min_version)
#     139                 return None
#     140             elif errors == "raise":
# --> 141                 raise ImportError(msg)
#     142
#     143     return module
#
# ...

# %%
h5_data['obj1'] = form_file
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-165-92cf74f169d4> in <module>()
# ----> 1 h5_data['obj1'] = form_file
#
# NameError: name 'h5_data' is not defined

# %%
h5_data['obj1']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-166-5c11f746f443> in <module>()
# ----> 1 h5_data['obj1']
#
# NameError: name 'h5_data' is not defined

# %%
h5_data.put('obj2' ,form_file,format='table' )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-167-e91d8faed8bd> in <module>()
# ----> 1 h5_data.put('obj2' ,form_file,format='table' )
#
# NameError: name 'h5_data' is not defined

# %%
h5_data.select('obj2' ,where =['index >= 10 and index <=15']  )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-168-6a7850debf99> in <module>()
# ----> 1 h5_data.select('obj2' ,where =['index >= 10 and index <=15']  )
#
# NameError: name 'h5_data' is not defined

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.tail(2)
# Out:
#      PassengerId  Survived  Pclass  ...   Fare Cabin  Embarked
# 889          890         1       1  ...  30.00  C148         C
# 890          891         0       3  ...   7.75   NaN         Q
#
# [2 rows x 12 columns]

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
df.dtypes=='float64'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# Cabin          False
# Embarked       False
# dtype: bool

# %%
df[["Name" , 'Fare']]
# Out:
#                                                   Name     Fare
# 0                              Braund, Mr. Owen Harris   7.2500
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  71.2833
# 2                               Heikkinen, Miss. Laina   7.9250
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000
# 4                             Allen, Mr. William Henry   8.0500
# ..                                                 ...      ...
# 886                              Montvila, Rev. Juozas  13.0000
# 887                       Graham, Miss. Margaret Edith  30.0000
# 888           Johnston, Miss. Catherine Helen "Carrie"  23.4500
# 889                              Behr, Mr. Karl Howell  30.0000
# 890                                Dooley, Mr. Patrick   7.7500
#
# [891 rows x 2 columns]

# %%
df[df.dtypes[df.dtypes== 'float64'].index]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
df['Name'][5:10:2]
# Out:
# 5                       Moran, Mr. James
# 7         Palsson, Master. Gosta Leonard
# 9    Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
sorted(df['Ticket'])
# Out:
# ['110152',
#  '110152',
#  '110152',
#  '110413',
#  '110413',
#  '110413',
#  '110465',
#  '110465',
#  '110564',
#  '110813',
#  '111240',
#  '111320',
#  '111361',
#  '111361',
#  '111369',
#  '111426',
#  '111427',
#  '111428',
#  '112050',
#  '112052',
#  '112053',
#  '112058',
#  '112059',
#  '112277',
#  '112379',
#  '113028',
#  '113043',
#  '113050',
#  '113051',
#  '113055',
#  '113056',
#  '113059',
#  '113501',
#  '113503',
#  '113505',
#  '113505',
#  '113509',
#  '113510',
#  '113514',
#  '113572',
#  '113572',
#  '113760',
#  '113760',
#  '113760',
#  '113760',
#  '113767',
#  '113773',
#  '113776',
#  '113776',
#  '113781',
#  '113781',
#  '113781',
#  '113781',
#  '113783',
#  '113784',
#  '113786',
#  '113787',
#  '113788',
#  '113789',
#  '113789',
#  '113792',
#  '113794',
#  '113796',
#  '113798',
#  '113798',
#  '113800',
#  '113803',
#  '113803',
#  '113804',
#  '113806',
#  '113806',
#  '113807',
#  '11668',
#  '11668',
#  '11751',
#  '11751',
#  '11752',
# ...

# %%
for i in df.columns : 
    print(df[[i]])
# Out:
#      PassengerId
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
# ..           ...
# 886          887
# 887          888
# 888          889
# 889          890
# 890          891
#
# [891 rows x 1 columns]
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 1 columns]
#      Pclass
# 0         3
# 1         1
# 2         3
# 3         1
# 4         3
# ..      ...
# 886       2
# 887       1
# 888       3
# 889       1
# 890       3
#
# [891 rows x 1 columns]
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# ...

# %%
df['sudh'] = df['PassengerId']
df
# Out:
#      PassengerId  Survived  Pclass  ... Cabin Embarked  sudh
# 0              1         0       3  ...   NaN        S     1
# 1              2         1       1  ...   C85        C     2
# 2              3         1       3  ...   NaN        S     3
# 3              4         1       1  ...  C123        S     4
# 4              5         0       3  ...   NaN        S     5
# ..           ...       ...     ...  ...   ...      ...   ...
# 886          887         0       2  ...   NaN        S   887
# 887          888         1       1  ...   B42        S   888
# 888          889         0       3  ...   NaN        S   889
# 889          890         1       1  ...  C148        C   890
# 890          891         0       3  ...   NaN        Q   891
#
# [891 rows x 13 columns]

# %%
pd.Categorical(df['Sex'])
# Out:
# ['male', 'female', 'female', 'female', 'male', ..., 'male', 'female', 'female', 'male', 'male']
# Length: 891
# Categories (2, object): ['female', 'male']

# %%
pd.Categorical(df['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
ser = df['Cabin'][df['Cabin'].isnull() == True]

# %%
len(ser.index)
# Out:
# 687

# %%
df.iloc[ser.index]
# Out:
#      PassengerId  Survived  Pclass  ... Cabin Embarked  sudh
# 0              1         0       3  ...   NaN        S     1
# 2              3         1       3  ...   NaN        S     3
# 4              5         0       3  ...   NaN        S     5
# 5              6         0       3  ...   NaN        Q     6
# 7              8         0       3  ...   NaN        S     8
# ..           ...       ...     ...  ...   ...      ...   ...
# 884          885         0       3  ...   NaN        S   885
# 885          886         0       3  ...   NaN        Q   886
# 886          887         0       2  ...   NaN        S   887
# 888          889         0       3  ...   NaN        S   889
# 890          891         0       3  ...   NaN        Q   891
#
# [687 rows x 13 columns]

# %%
df[df['Fare'] == max(df['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
df['new_col'] = df['PassengerId']  + df['Age']
df
# Out:
#      PassengerId  Survived  Pclass  ... Embarked sudh  new_col
# 0              1         0       3  ...        S    1     23.0
# 1              2         1       1  ...        C    2     40.0
# 2              3         1       3  ...        S    3     29.0
# 3              4         1       1  ...        S    4     39.0
# 4              5         0       3  ...        S    5     40.0
# ..           ...       ...     ...  ...      ...  ...      ...
# 886          887         0       2  ...        S  887    914.0
# 887          888         1       1  ...        S  888    907.0
# 888          889         0       3  ...        S  889      NaN
# 889          890         1       1  ...        C  890    916.0
# 890          891         0       3  ...        Q  891    923.0
#
# [891 rows x 14 columns]

# %%
df5 = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',sep= '\t')
df5
# Out:
#       order_id  ...  item_price
# 0            1  ...      $2.39
# 1            1  ...      $3.39
# 2            1  ...      $3.39
# 3            1  ...      $2.39
# 4            2  ...     $16.98
# ...        ...  ...         ...
# 4617      1833  ...     $11.75
# 4618      1833  ...     $11.75
# 4619      1834  ...     $11.25
# 4620      1834  ...      $8.75
# 4621      1834  ...      $8.75
#
# [4622 rows x 5 columns]

# %%
df5.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %% [markdown]
# https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv
#
# https://raw.githubusercontent.com/justmarkham/DAT8/master/data/beer.txt
#
# https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv
#
# https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv
#
# https://drive.google.com/file/d/1etGP85wJWsgqbsh3gX5oxc8dPKLMA1eT/view

# %% [markdown]
# 26 ) Working with Pandas

# %%
import pandas as pd  
titanic_train = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv",sep=',')   
titanic_train
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
dy = titanic_train.dtypes
dy
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
dy['Pclass']
# Out:
# dtype('int64')

# %%
dy[0:100:2]
# Out:
# PassengerId     int64
# Pclass          int64
# Sex            object
# SibSp           int64
# Ticket         object
# Cabin          object
# dtype: object

# %%
type(titanic_train['Age'])
# Out:
# pandas.core.series.Series

# %%
titanic_train['Age'][-1] # unlike list we cannot access the data with negative values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-207-aeedf62ded2b> in <module>()
# ----> 1 titanic_train['Age'][-1]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ...

# %%
titanic_train['Age'][::2]
# Out:
# 0      22.0
# 2      26.0
# 4      35.0
# 6      54.0
# 8      27.0
#        ...
# 882    22.0
# 884    25.0
# 886    27.0
# 888     NaN
# 890    32.0
# Name: Age, Length: 446, dtype: float64

# %%
list(titanic_train['Age'][::2])

# %%
titanic_train_cat = titanic_train[titanic_train.dtypes[titanic_train.dtypes == 'object'].index]

# %%
type(titanic_train.dtypes[titanic_train.dtypes == 'object'])
# Out:
# pandas.core.series.Series

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'sudh', 'new_col'],
#       dtype='object')

# %%
titanic_train.dtypes[titanic_train.dtypes == 'object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
titanic_train_cat.describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
import numpy as np

# %%
titanic_train_age_null = np.where(titanic_train['Age'].isnull() == True)
titanic_train_age_null
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
#         196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
#         270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
#         334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
#         409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
#         459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
#         511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
#         564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
#         613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
#         692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
#         773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
# ...

# %%
titanic_train[titanic_train['Age'].isnull() == True]
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 5              6         0       3  ...   8.4583   NaN         Q
# 17            18         1       2  ...  13.0000   NaN         S
# 19            20         1       3  ...   7.2250   NaN         C
# 26            27         0       3  ...   7.2250   NaN         C
# 28            29         1       3  ...   7.8792   NaN         Q
# ..           ...       ...     ...  ...      ...   ...       ...
# 859          860         0       3  ...   7.2292   NaN         C
# 863          864         0       3  ...  69.5500   NaN         S
# 868          869         0       3  ...   9.5000   NaN         S
# 878          879         0       3  ...   7.8958   NaN         S
# 888          889         0       3  ...  23.4500   NaN         S
#
# [177 rows x 12 columns]

# %%
titanic_train.iloc[titanic_train_age_null]
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 5              6         0       3  ...   8.4583   NaN         Q
# 17            18         1       2  ...  13.0000   NaN         S
# 19            20         1       3  ...   7.2250   NaN         C
# 26            27         0       3  ...   7.2250   NaN         C
# 28            29         1       3  ...   7.8792   NaN         Q
# ..           ...       ...     ...  ...      ...   ...       ...
# 859          860         0       3  ...   7.2292   NaN         C
# 863          864         0       3  ...  69.5500   NaN         S
# 868          869         0       3  ...   9.5000   NaN         S
# 878          879         0       3  ...   7.8958   NaN         S
# 888          889         0       3  ...  23.4500   NaN         S
#
# [177 rows x 12 columns]

# %%
titanic_train.iloc[5]
# Out:
# PassengerId                   6
# Survived                      0
# Pclass                        3
# Name           Moran, Mr. James
# Sex                        male
# Age                         NaN
# SibSp                         0
# Parch                         0
# Ticket                   330877
# Fare                     8.4583
# Cabin                       NaN
# Embarked                      Q
# Name: 5, dtype: object

# %%
titanic_train.iloc[[1,2,3,6,7]]
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 6            7         0       1  ...  51.8625   E46         S
# 7            8         0       3  ...  21.0750   NaN         S
#
# [5 rows x 12 columns]

# %%
titanic_train.iloc[np.where(titanic_train['Fare'] == max(titanic_train['Fare']))]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
titanic_train[titanic_train['Fare']==titanic_train['Fare'].max()]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
titanic_train[titanic_train['Age']==24.0]['Name']
# Out:
# 89                                Celotti, Mr. Francesco
# 118                             Baxter, Mr. Quigg Edmond
# 127                            Madsen, Mr. Fridtjof Arne
# 139                                   Giglio, Mr. Victor
# 142    Hakkarainen, Mrs. Pekka Pietari (Elin Matilda ...
# 199               Yrois, Miss. Henriette ("Mrs Harbeck")
# 210                                       Ali, Mr. Ahmed
# 234                    Leyson, Mr. Robert William Norman
# 247                      Hamalainen, Mrs. William (Anna)
# 293                                  Haas, Miss. Aloisia
# 294                                     Mineff, Mr. Ivan
# 310                       Hays, Miss. Margaret Bechstein
# 316                  Kantor, Mrs. Sinai (Miriam Sternin)
# 341                       Fortune, Miss. Alice Elizabeth
# 345                        Brown, Miss. Amelia "Mildred"
# 369                        Aubart, Mme. Leontine Pauline
# ...

# %%
titanic_train[titanic_train['Age'] == titanic_train['Age'].min()]['Name']
# Out:
# 803    Thomas, Master. Assad Alexander
# Name: Name, dtype: object

# %%
titanic_train['Age'][titanic_train['Cabin'].isnull()]
# Out:
# 0      22.0
# 2      26.0
# 4      35.0
# 5       NaN
# 7       2.0
#        ...
# 884    25.0
# 885    39.0
# 886    27.0
# 888     NaN
# 890    32.0
# Name: Age, Length: 687, dtype: float64

# %%
titanic_train[['Age','Cabin']][titanic_train.Cabin.isnull()==True]
# Out:
#       Age Cabin
# 0    22.0   NaN
# 2    26.0   NaN
# 4    35.0   NaN
# 5     NaN   NaN
# 7     2.0   NaN
# ..    ...   ...
# 150  51.0   NaN
# 152  55.5   NaN
# 153  40.5   NaN
# 154   NaN   NaN
# 155  51.0   NaN
#
# [125 rows x 2 columns]

# %%
titanic_train[titanic_train['Cabin']  == 'NaN']
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
titanic_train[titanic_train['Cabin'] == 'NaN']['Age']
# Out:
# Series([], Name: Age, dtype: float64)

# %%
titanic_train[titanic_train["Cabin"].isnull()]["Age"]
# Out:
# 0      22.0
# 2      26.0
# 4      35.0
# 5       NaN
# 7       2.0
#        ...
# 150    51.0
# 152    55.5
# 153    40.5
# 154     NaN
# 155    51.0
# Name: Age, Length: 125, dtype: float64

# %%
titanic_train['Cabin'] == 'NaN'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154    False
# 155    False
# Name: Cabin, Length: 156, dtype: bool

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_train.iloc[np.where(titanic_train['Cabin'].isnull() == True)][['Age','Cabin']]
# Out:
#       Age Cabin
# 0    22.0   NaN
# 2    26.0   NaN
# 4    35.0   NaN
# 5     NaN   NaN
# 7     2.0   NaN
# ..    ...   ...
# 150  51.0   NaN
# 152  55.5   NaN
# 153  40.5   NaN
# 154   NaN   NaN
# 155  51.0   NaN
#
# [125 rows x 2 columns]

# %%
titanic_train.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
titanic_train.Name[(titanic_train.Survived == 1) & (titanic_train.Sex == "male")]
# Out:
# 17                     Williams, Mr. Charles Eugene
# 21                            Beesley, Mr. Lawrence
# 23                     Sloper, Mr. William Thompson
# 36                                 Mamee, Mr. Hanna
# 55                                Woolner, Mr. Hugh
# 65                         Moubarek, Master. Gerios
# 74                                    Bing, Mr. Lee
# 78                    Caldwell, Master. Alden Gates
# 81                      Sheerlinck, Mr. Jan Baptist
# 97                  Greenfield, Mr. William Bertram
# 107                          Moss, Mr. Albert Johan
# 125                    Nicola-Yarred, Master. Elias
# 127                       Madsen, Mr. Fridtjof Arne
# 146    Andersson, Mr. August Edvard ("Wennerstrom")
# Name: Name, dtype: object

# %%
titanic_train.Name[(titanic_train.Survived == 0) & (titanic_train.Sex == "male")]
# Out:
# 0              Braund, Mr. Owen Harris
# 4             Allen, Mr. William Henry
# 5                     Moran, Mr. James
# 6              McCarthy, Mr. Timothy J
# 7       Palsson, Master. Gosta Leonard
#                     ...
# 150         Bateman, Rev. Robert James
# 152                   Meo, Mr. Alfonzo
# 153    van Billiard, Mr. Austin Blyler
# 154              Olsen, Mr. Ole Martin
# 155        Williams, Mr. Charles Duane
# Name: Name, Length: 86, dtype: object

# %%
titanic_train['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 151                    Pears, Mrs. Thomas (Edith Wearne)
# 152                                     Meo, Mr. Alfonzo
# 153                      van Billiard, Mr. Austin Blyler
# 154                                Olsen, Mr. Ole Martin
# 155                          Williams, Mr. Charles Duane
# Name: Name, Length: 156, dtype: object

# %%
titanic_train.Name
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 151                    Pears, Mrs. Thomas (Edith Wearne)
# 152                                     Meo, Mr. Alfonzo
# 153                      van Billiard, Mr. Austin Blyler
# 154                                Olsen, Mr. Ole Martin
# 155                          Williams, Mr. Charles Duane
# Name: Name, Length: 156, dtype: object

# %%
titanic_train[(titanic_train['Sex']== 'male') & (titanic_train['Survived']== 1)]['Name']
# Out:
# 17                     Williams, Mr. Charles Eugene
# 21                            Beesley, Mr. Lawrence
# 23                     Sloper, Mr. William Thompson
# 36                                 Mamee, Mr. Hanna
# 55                                Woolner, Mr. Hugh
# 65                         Moubarek, Master. Gerios
# 74                                    Bing, Mr. Lee
# 78                    Caldwell, Master. Alden Gates
# 81                      Sheerlinck, Mr. Jan Baptist
# 97                  Greenfield, Mr. William Bertram
# 107                          Moss, Mr. Albert Johan
# 125                    Nicola-Yarred, Master. Elias
# 127                       Madsen, Mr. Fridtjof Arne
# 146    Andersson, Mr. August Edvard ("Wennerstrom")
# Name: Name, dtype: object

# %%
titanic_train['new_col'] = "sudh"

# %%
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
l = [1,2,3,4,5]

# %%
pd.Series(l)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
d = {'key' : "sudh" , "title" :"kumar" , "mail_id" : "sudha@gmail.com"}

# %%
pd.DataFrame(d,index=['key' , 'title' , 'mail_id'])
# Out:
#           key  title          mail_id
# key      sudh  kumar  sudha@gmail.com
# title    sudh  kumar  sudha@gmail.com
# mail_id  sudh  kumar  sudha@gmail.com

# %%
pd.Series(d)
# Out:
# key                   sudh
# title                kumar
# mail_id    sudha@gmail.com
# dtype: object

# %%
arr  = np.random.randn(3,4)

# %%
pd.DataFrame(arr)
# Out:
#           0         1         2         3
# 0  0.249873 -0.894455 -1.157412 -1.166982
# 1 -0.803732  2.011122 -0.396354 -0.999178
# 2 -0.763614 -1.364206  0.064865 -0.326826

# %%
pd.Series(arr)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-123-409226d0ba63> in <module>
# ----> 1 pd.Series(arr)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     325                     data = data.copy()
#     326             else:
# --> 327                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     328
#     329                 data = SingleBlockManager.from_array(data, index)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     494     elif subarr.ndim > 1:
#     495         if isinstance(data, np.ndarray):
# --> 496             raise Exception("Data must be 1-dimensional")
#     497         else:
# ...

# %%
ser = pd.Series(np.array([4,5,6,7,8]),index=['a','b','sudh',"kumar",'c'])

# %%
ser
# Out:
# a        4
# b        5
# sudh     6
# kumar    7
# c        8
# dtype: int32

# %%
ser['sudh']
# Out:
# 6

# %%
ser.iloc[0]
# Out:
# 4

# %%
ser.loc['sudh']
# Out:
# 6

# %%
ser['sudh']
# Out:
# 6

# %%
ser1 = pd.Series(np.array([4,5,6,7,8]),index=[45,51,62,"sudh",83])

# %%
ser1
# Out:
# 45      4
# 51      5
# 62      6
# sudh    7
# 83      8
# dtype: int32

# %%
ser1.loc[51]
# Out:
# 5

# %%
df = pd.DataFrame(np.random.randint(3,6,(4,5)),index=['a','b','c','d'],columns=['x','y','z','u','v'])

# %%
df
# Out:
#    x  y  z  u  v
# a  4  5  5  3  3
# b  4  4  3  4  4
# c  4  5  5  5  3
# d  3  3  4  4  5

# %%
df.loc[['c','d'],['z','u']]
# Out:
#    z  u
# c  5  5
# d  4  4

# %%
df.iloc[[2,3],[2,3]]
# Out:
#    z  u
# c  5  5
# d  4  4

# %%
df.iloc[2:,2:4]
# Out:
#    z  u
# c  5  5
# d  4  4

# %%
df
# Out:
#    x  y  z  u  v
# a  4  5  5  3  3
# b  4  4  3  4  4
# c  4  5  5  5  3
# d  3  3  4  4  5

# %%
df['new'] = df['x'] + df.y

# %%
df
# Out:
#    x  y  z  u  v  new
# a  4  5  5  3  3    9
# b  4  4  3  4  4    8
# c  4  5  5  5  3    9
# d  3  3  4  4  5    6

# %%
df.drop('x',axis=1,inplace=True)

# %%
df
# Out:
#    y  z  u  v  new
# a  5  5  3  3    9
# b  4  3  4  4    8
# c  5  5  5  3    9
# d  3  4  4  5    6

# %%
df = df.drop('a')

# %%
df
# Out:
#    y  z  u  v  new
# b  4  3  4  4    8
# d  3  4  4  5    6

# %%
np.random.seed(23)
df = pd.DataFrame(np.random.randn(4,5),index=['a','b','c','d'],columns=['x','y','z','u','v'])

# %%
df
# Out:
#           x         y         z         u         v
# a  0.666988  0.025813 -0.777619  0.948634  0.701672
# b -1.051082 -0.367548 -1.137460 -1.322148  1.772258
# c -0.347459  0.670140  0.322272  0.060343 -1.043450
# d -1.009942  0.441736  1.128877 -1.838068 -0.938769

# %%
df[df<0]
# Out:
#           x         y         z         u         v
# a       NaN       NaN -0.777619       NaN       NaN
# b -1.051082 -0.367548 -1.137460 -1.322148       NaN
# c -0.347459       NaN       NaN       NaN -1.043450
# d -1.009942       NaN       NaN -1.838068 -0.938769

# %%
df.values[df.values<0]
# Out:
# array([-0.77761941, -1.05108156, -0.36754812, -1.13745969, -1.32214752,
#        -0.34745899, -1.04345   , -1.00994188, -1.83806777, -0.93876863])

# %%
df.values[df.iloc[0:5]<0]
# Out:
# array([-0.77761941, -1.05108156, -0.36754812, -1.13745969, -1.32214752,
#        -0.34745899, -1.04345   , -1.00994188, -1.83806777, -0.93876863])

# %%
c = df.values[df.values<0]
for i in df.columns:
    for j in df.index:
        if df.loc[j,i] in c:
            print(i,j)
# Out:
# x b
# x c
# x d
# y b
# z a
# z b
# u b
# u d
# v c
# v d

# %%
l = df.values[df<0]
for c in df.columns:
    for v in df.index:
        if df[c][v] in l:
            print(c,v,df[c][v])
# Out:
# x b -1.0510815639071178
# x c -0.34745899102186334
# x d -1.0099418765878465
# y b -0.3675481161171661
# z a -0.7776194131918178
# z b -1.1374596907250272
# u b -1.3221475225908594
# u d -1.8380677677579502
# v c -1.0434500017467254
# v d -0.9387686311201282

# %%
for i in df.columns:
    for j in df.index:
        if df.loc[j,i]<0:
            print(i,j,df.loc[j,i])
# Out:
# x b -1.0510815639071178
# x c -0.34745899102186334
# x d -1.0099418765878465
# y b -0.3675481161171661
# z a -0.7776194131918178
# z b -1.1374596907250272
# u b -1.3221475225908594
# u d -1.8380677677579502
# v c -1.0434500017467254
# v d -0.9387686311201282

# %%
for i in df.columns:
    for j in df.index:
        for k in df.values[df.values<0]:
            print(k,"----",(i,j))
# Out:
# -0.7776194131918178 ---- ('x', 'a')
# -1.0510815639071178 ---- ('x', 'a')
# -0.3675481161171661 ---- ('x', 'a')
# -1.1374596907250272 ---- ('x', 'a')
# -1.3221475225908594 ---- ('x', 'a')
# -0.34745899102186334 ---- ('x', 'a')
# -1.0434500017467254 ---- ('x', 'a')
# -1.0099418765878465 ---- ('x', 'a')
# -1.8380677677579502 ---- ('x', 'a')
# -0.9387686311201282 ---- ('x', 'a')
# -0.7776194131918178 ---- ('x', 'b')
# -1.0510815639071178 ---- ('x', 'b')
# -0.3675481161171661 ---- ('x', 'b')
# -1.1374596907250272 ---- ('x', 'b')
# -1.3221475225908594 ---- ('x', 'b')
# -0.34745899102186334 ---- ('x', 'b')
# -1.0434500017467254 ---- ('x', 'b')
# -1.0099418765878465 ---- ('x', 'b')
# -1.8380677677579502 ---- ('x', 'b')
# -0.9387686311201282 ---- ('x', 'b')
# -0.7776194131918178 ---- ('x', 'c')
# -1.0510815639071178 ---- ('x', 'c')
# -0.3675481161171661 ---- ('x', 'c')
# -1.1374596907250272 ---- ('x', 'c')
# -1.3221475225908594 ---- ('x', 'c')
# -0.34745899102186334 ---- ('x', 'c')
# ...

# %%
k=df<0
for i in k.columns:
    for j in k.index:
        if k[i][j]==True:
            print(i,j)
# Out:
# x b
# x c
# x d
# y b
# z a
# z b
# u b
# u d
# v c
# v d

# %%
d = {'key1':[1,2,3,4,np.nan],"key2":["sudh" ,"kumar" , np.nan,5,6] ,'key3' :[np.nan,np.nan,np.nan,3,8]}
df = pd.DataFrame(d)

# %%
df
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna()
# Out:
#    key1 key2  key3
# 3   4.0    5   3.0

# %%
df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
df
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=0)
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=1)
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=2)
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=3)
# Out:
#    key1 key2  key3
# 3   4.0    5   3.0

# %%
df
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=4)
# Out:
# Empty DataFrame
# Columns: [key1, key2, key3]
# Index: []

# %%
df.dropna(axis=1 , thresh=3)
# Out:
#    key1   key2
# 0   1.0   sudh
# 1   2.0  kumar
# 2   3.0    NaN
# 3   4.0      5
# 4   NaN      6

# %%
df
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.fillna(567)
# Out:
#     key1   key2   key3
# 0    1.0   sudh  567.0
# 1    2.0  kumar  567.0
# 2    3.0    567  567.0
# 3    4.0      5    3.0
# 4  567.0      6    8.0

# %%
df.fillna(value=df['key1'].mean())
# Out:
#    key1   key2  key3
# 0   1.0   sudh   2.5
# 1   2.0  kumar   2.5
# 2   3.0    2.5   2.5
# 3   4.0      5   3.0
# 4   2.5      6   8.0

# %%
df
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
d1 = {'name' :['sudh' , 'visal' , 'umang', 'vishal' ,'umang'],"mail_id" :["sudh@gmail.com", "vishal@gmail.com",'umang@gmail.com','vishal@gmail.com','umang@gmail.com'],
     'salary' :[100,200,500,200,500]}

# %%
df = pd.DataFrame(d1)

# %%
df
# Out:
#      name           mail_id  salary
# 0    sudh    sudh@gmail.com     100
# 1   visal  vishal@gmail.com     200
# 2   umang   umang@gmail.com     500
# 3  vishal  vishal@gmail.com     200
# 4   umang   umang@gmail.com     500

# %%
df.groupby('mail_id').mean()
# Out:
#                   salary
# mail_id
# sudh@gmail.com       100
# umang@gmail.com      500
# vishal@gmail.com     200

# %%
df.groupby('mail_id').sum()
# Out:
#                   salary
# mail_id
# sudh@gmail.com       100
# umang@gmail.com     1000
# vishal@gmail.com     400

# %%
type(df.groupby('mail_id').describe())
# Out:
# pandas.core.frame.DataFrame

# %%
df.groupby('mail_id').describe()
# Out:
#                  salary
#                   count   mean  std    min    25%    50%    75%    max
# mail_id
# sudh@gmail.com      1.0  100.0  NaN  100.0  100.0  100.0  100.0  100.0
# umang@gmail.com     2.0  500.0  0.0  500.0  500.0  500.0  500.0  500.0
# vishal@gmail.com    2.0  200.0  0.0  200.0  200.0  200.0  200.0  200.0

# %%
df.groupby('mail_id').describe().loc['umang@gmail.com']
# Out:
# salary  count      2.0
#         mean     500.0
#         std        0.0
#         min      500.0
#         25%      500.0
#         50%      500.0
#         75%      500.0
#         max      500.0
# Name: umang@gmail.com, dtype: float64

# %%
df.groupby('mail_id').describe().loc['umang@gmail.com']['salary']['mean']
# Out:
# 500.0

# %%
df.groupby('mail_id').describe().T
# Out:
# mail_id       sudh@gmail.com  umang@gmail.com  vishal@gmail.com
# salary count             1.0              2.0               2.0
#        mean            100.0            500.0             200.0
#        std               NaN              0.0               0.0
#        min             100.0            500.0             200.0
#        25%             100.0            500.0             200.0
#        50%             100.0            500.0             200.0
#        75%             100.0            500.0             200.0
#        max             100.0            500.0             200.0

# %%
df.groupby('mail_id').describe()
# Out:
#                  salary
#                   count   mean  std    min    25%    50%    75%    max
# mail_id
# sudh@gmail.com      1.0  100.0  NaN  100.0  100.0  100.0  100.0  100.0
# umang@gmail.com     2.0  500.0  0.0  500.0  500.0  500.0  500.0  500.0
# vishal@gmail.com    2.0  200.0  0.0  200.0  200.0  200.0  200.0  200.0

# %%
arr1 = np.random.randn(3,4)

# %%
arr2 = np.random.randn(3,4)

# %%
arr3 = np.random.randn(3,4)

# %%
df1 = pd.DataFrame(arr1,columns=["A","B","C","D"],index = [0,1,2])

# %%
df2 = pd.DataFrame(arr2,columns=["A","B","C","D"],index = [3,4,5])

# %%
df2
# Out:
#           A         B         C         D
# 0 -0.071324 -0.045438  1.040886 -0.094035
# 1 -0.420844 -0.551989 -0.121098  0.190141
# 2  0.512137  0.131538 -0.331617 -1.632386

# %%
df3 = pd.DataFrame(arr3,columns=["A","B","C","D"],index = [6,7,8])

# %%
df1
# Out:
#           A         B         C         D
# 0  0.728876  1.968435 -0.547788 -0.679418
# 1 -2.506230  0.146960  0.606195 -0.022539
# 2  0.013422  0.935945  0.420623  0.411620

# %%
df2
# Out:
#           A         B         C         D
# 0 -0.071324 -0.045438  1.040886 -0.094035
# 1 -0.420844 -0.551989 -0.121098  0.190141
# 2  0.512137  0.131538 -0.331617 -1.632386

# %%
df3
# Out:
#           A         B         C         D
# 0  0.619114 -0.992574 -0.161346  1.192404
# 1  0.250737 -0.813616  0.703624 -0.268142
# 2 -0.482559  1.244610  0.676860  3.187503

# %%
df4 = pd.concat([df1,df2,df3])

# %%
df5 = pd.concat([df1,df2,df3],axis=1)

# %%
df4
# Out:
#           A         B         C         D
# 0  0.728876  1.968435 -0.547788 -0.679418
# 1 -2.506230  0.146960  0.606195 -0.022539
# 2  0.013422  0.935945  0.420623  0.411620
# 0 -0.071324 -0.045438  1.040886 -0.094035
# 1 -0.420844 -0.551989 -0.121098  0.190141
# 2  0.512137  0.131538 -0.331617 -1.632386
# 0  0.619114 -0.992574 -0.161346  1.192404
# 1  0.250737 -0.813616  0.703624 -0.268142
# 2 -0.482559  1.244610  0.676860  3.187503

# %%
df4.iloc[0]
# Out:
# A    0.728876
# B    1.968435
# C   -0.547788
# D   -0.679418
# Name: 0, dtype: float64

# %%
df4.loc[0]
# Out:
#           A         B         C         D
# 0  0.728876  1.968435 -0.547788 -0.679418
# 0 -0.071324 -0.045438  1.040886 -0.094035
# 0  0.619114 -0.992574 -0.161346  1.192404

# %%
df5
# Out:
#           A         B         C         D         A         B         C  \
# 0  0.728876  1.968435 -0.547788 -0.679418 -0.071324 -0.045438  1.040886
# 1 -2.506230  0.146960  0.606195 -0.022539 -0.420844 -0.551989 -0.121098
# 2  0.013422  0.935945  0.420623  0.411620  0.512137  0.131538 -0.331617
#
#           D         A         B         C         D
# 0 -0.094035  0.619114 -0.992574 -0.161346  1.192404
# 1  0.190141  0.250737 -0.813616  0.703624 -0.268142
# 2 -1.632386 -0.482559  1.244610  0.676860  3.187503

# %%
df5['A']
# Out:
#           A         A         A
# 0  0.728876 -0.071324  0.619114
# 1 -2.506230 -0.420844  0.250737
# 2  0.013422  0.512137 -0.482559

# %%
df5.iloc[:,4]
# Out:
# 0   -0.071324
# 1   -0.420844
# 2    0.512137
# Name: A, dtype: float64

# %%
pd.concat([df1,df2,df3],axis=1).fillna(0)
# Out:
#           A         B         C         D         A         B         C  \
# 0  0.728876  1.968435 -0.547788 -0.679418  0.000000  0.000000  0.000000
# 1 -2.506230  0.146960  0.606195 -0.022539  0.000000  0.000000  0.000000
# 2  0.013422  0.935945  0.420623  0.411620  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.000000 -0.071324 -0.045438  1.040886
# 4  0.000000  0.000000  0.000000  0.000000 -0.420844 -0.551989 -0.121098
# 5  0.000000  0.000000  0.000000  0.000000  0.512137  0.131538 -0.331617
# 6  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#           D         A         B         C         D
# 0  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  0.000000  0.000000
# ...

# %%
df1
# Out:
#           A         B         C         D
# 0  0.728876  1.968435 -0.547788 -0.679418
# 1 -2.506230  0.146960  0.606195 -0.022539
# 2  0.013422  0.935945  0.420623  0.411620

# %%
df2
# Out:
#           A         B         C         D
# 3 -0.071324 -0.045438  1.040886 -0.094035
# 4 -0.420844 -0.551989 -0.121098  0.190141
# 5  0.512137  0.131538 -0.331617 -1.632386

# %%
np.random.seed(23)
arr1 = np.random.randn(3,4)
np.random.seed(23)
arr2 = np.random.randn(3,4)
df11 = pd.DataFrame(arr1,columns=["A","B","C","D"],index = [0,1,2])
df22 = pd.DataFrame(arr2,columns=["A","B","C","D"],index = [3,4,5])

# %%
df11
# Out:
#           A         B         C         D
# 0  0.666988  0.025813 -0.777619  0.948634
# 1  0.701672 -1.051082 -0.367548 -1.137460
# 2 -1.322148  1.772258 -0.347459  0.670140

# %%
df22
# Out:
#           A         B         C         D
# 3  0.666988  0.025813 -0.777619  0.948634
# 4  0.701672 -1.051082 -0.367548 -1.137460
# 5 -1.322148  1.772258 -0.347459  0.670140

# %%
pd.merge(df11,df22,on= "A")
# Out:
#           A       B_x       C_x       D_x       B_y       C_y       D_y
# 0  0.666988  0.025813 -0.777619  0.948634  0.025813 -0.777619  0.948634
# 1  0.701672 -1.051082 -0.367548 -1.137460 -1.051082 -0.367548 -1.137460
# 2 -1.322148  1.772258 -0.347459  0.670140  1.772258 -0.347459  0.670140

# %%
df1 = pd.DataFrame({'key': ['K0', 'K8', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
   
df2 = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                          'D': ['D0', 'D1', 'D2', 'D3']})

# %%
df1
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K8  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
df2
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
pd.merge(df1,df2,on= 'key',how = 'outer')
# Out:
#   key    A    B    C    D
# 0  K0   A0   B0   C0   D0
# 1  K8   A1   B1  NaN  NaN
# 2  K2   A2   B2   C2   D2
# 3  K3   A3   B3   C3   D3
# 4  K1  NaN  NaN   C1   D1

# %%
df1 = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                        'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3']})
    
df2 = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                               'key2': ['K0', 'K0', 'K0', 'K0'],
                                  'C': ['C0', 'C1', 'C2', 'C3'],
                                  'D': ['D0', 'D1', 'D2', 'D3']})

# %%
df1
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3

# %%
df2
# Out:
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
pd.merge(df1,df2,on = ['key1','key2'])
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                      index=['K0', 'K1', 'K2']) 

df2 = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                    'D': ['D0', 'D2', 'D3']},
                      index=['K0', 'K2', 'K3'])

# %%
df1
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
df2
# Out:
#      C   D
# K0  C0  D0
# K2  C2  D2
# K3  C3  D3

# %%
df1.join(df2,how = 'outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3
